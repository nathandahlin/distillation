# %%
from dqn.agent import CarRacingDQN
import os
import tensorflow as tf
import gym
import _thread
import re
import sys

import h5py

from matplotlib import pyplot as plt

import numpy as np

#from car_racing import CarRacingFixed
#from car_racing_ellipse import CarRacingEllipse
from car_racing_square import CarRacingSquare

model_config = dict(
    min_epsilon=0.1,
    max_negative_rewards=12,
    min_experience_size=int(1e4),
    num_frame_stack=1,
    frame_skip=3,
    train_freq=4,
    batchsize=64,
    epsilon_decay_steps=int(1e5),
    network_update_freq=int(1e3),
    experience_capacity=int(4e4),
    gamma=0.95
)

#env_name = "CarRacing-v0"
#env = gym.make(env_name)

#env = CarRacingEllipse()
env = CarRacingSquare()

# tf.reset_default_graph()
dqn_agent = CarRacingDQN(env=env, **model_config)
dqn_agent.build_graph()
sess = tf.InteractiveSession()
dqn_agent.session = sess

saver = tf.train.Saver(max_to_keep=100)

#checkpoint_path = "data/checkpoint02"
checkpoint_path = 'data/zigzag'

rollouts_dir = os.path.join(checkpoint_path,'Rollouts')
if not 

print("loading the latest checkpoint from %s" % checkpoint_path)
ckpt = tf.train.get_checkpoint_state(checkpoint_path)
assert ckpt, "checkpoint path %s not found" % checkpoint_path
global_counter = int(re.findall("-(\d+)$", ckpt.model_checkpoint_path)[0]) 
saver.restore(sess, ckpt.model_checkpoint_path)
#dqn_agent.global_counter = global_counter

dqn_agent.do_training = False
dqn_agent.do_rollouts = True

save_freq_episodes = 5

print(dqn_agent.get_epsilon())
print(dqn_agent.global_counter)
# Out:
# /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# [2021-05-20 00:36:01,295] From /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# [2021-05-20 00:36:01,409] From /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# loading the latest checkpoint from data/square
# WARNING:tensorflow:From /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# [2021-05-20 00:36:01,704] From /home/dahlin/Desktop/Car Racing/car_racing_retry/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from data/square/m.ckpt-376958
# [2021-05-20 00:36:01,707] Restoring parameters from data/square/m.ckpt-376958
# 0.0
# 0

# %%
desired_len = 100000

frames_rollout = []
actions_rollout = []
rewards_rollout = []
step_rewards_rollout = []
dones_rollout = []
num_frames_rollout = []

#total_reward, frames_in_episode, eh = dqn_agent.play_episode(log_data=True)
total_reward, frames_in_episode, actions, frames = dqn_agent.play_episode()
#actions_rollout.extend(eh.actions[0:frames_in_episode])
#frames_rollout.extend(eh.frames[0:frames_in_episode])
actions_rollout.extend(actions)
frames_rollout.extend(frames)
#step_rewards_rollout.extend(step_rewards)
#dones_rollout.extend(dones)
rewards_rollout.append(total_reward)
num_frames_rollout.append(frames_in_episode)
print('Actions so far : '+str(len(actions_rollout)))
print("episode: %d, reward: %f, length: %d, total steps: %d" %
          (dqn_agent.episode_counter, total_reward, frames_in_episode, dqn_agent.global_counter))

while(len(actions_rollout)<desired_len):
    total_reward, frames_in_episode, actions, frames = dqn_agent.play_episode()
    #actions_rollout.extend(eh.actions[0:frames_in_episode])
    #frames_rollout.extend(eh.frames[0:frames_in_episode])
    actions_rollout.extend(actions)
    frames_rollout.extend(frames)
    rewards_rollout.append(total_reward)
    num_frames_rollout.append(frames_in_episode)
    print('Actions so far : '+str(len(actions_rollout)))
    print("episode: %d, reward: %f, length: %d, total steps: %d" %
          (dqn_agent.episode_counter, total_reward, frames_in_episode, dqn_agent.global_counter))
    save_cond = dqn_agent.episode_counter % save_freq_episodes == 0
    if save_cond:
        #f = h5py.File('dqn_rollouts'+str(desired_len)+'_frames_only.h5','w')
        f = h5py.File(checkpoint_path+'/dqn_rollouts.h5','w')
#f = h5py.File('dqn_rollouts'+str(104737)+'.h5','w')
        f.create_dataset('actions_rollout',data=actions_rollout)
        f.create_dataset('frames_rollout',data=frames_rollout)
        f.create_dataset('rewards_rollout',data=rewards_rollout)
        f.create_dataset('num_frames_rollouts',data=num_frames_rollout)
        #f.create_dataset('step_rewards_rollout',data=step_rewards_rollout)
        #f.create_dataset('dones_rollout',data=dones_rollout)
        f.close()
# Out:
# k generation: 1779..2220 -> 441-tiles track
# Actions so far : 49534
# episode: 142, reward: 874.845455, length: 349, total steps: 49534
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 49883
# episode: 143, reward: 874.845455, length: 349, total steps: 49883
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 50232
# episode: 144, reward: 874.845455, length: 349, total steps: 50232
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 50581
# episode: 145, reward: 874.845455, length: 349, total steps: 50581
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 50930
# episode: 146, reward: 874.845455, length: 349, total steps: 50930
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 51279
# episode: 147, reward: 874.845455, length: 349, total steps: 51279
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 51628
# episode: 148, reward: 874.845455, length: 349, total steps: 51628
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 51977
# episode: 149, reward: 874.845455, length: 349, total steps: 51977
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 52326
# episode: 150, reward: 874.845455, length: 349, total steps: 52326
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 52675
# episode: 151, reward: 874.845455, length: 349, total steps: 52675
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 53024
# episode: 152, reward: 874.845455, length: 349, total steps: 53024
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 53373
# episode: 153, reward: 874.845455, length: 349, total steps: 53373
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 53722
# episode: 154, reward: 874.845455, length: 349, total steps: 53722
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 54071
# episode: 155, reward: 874.845455, length: 349, total steps: 54071
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 54420
# episode: 156, reward: 874.845455, length: 349, total steps: 54420
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 54769
# episode: 157, reward: 874.845455, length: 349, total steps: 54769
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 55118
# episode: 158, reward: 874.845455, length: 349, total steps: 55118
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 55467
# episode: 159, reward: 874.845455, length: 349, total steps: 55467
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 55816
# episode: 160, reward: 874.845455, length: 349, total steps: 55816
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 56165
# episode: 161, reward: 874.845455, length: 349, total steps: 56165
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 56514
# episode: 162, reward: 874.845455, length: 349, total steps: 56514
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 56863
# episode: 163, reward: 874.845455, length: 349, total steps: 56863
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 57212
# episode: 164, reward: 874.845455, length: 349, total steps: 57212
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far : 57561
# episode: 165, reward: 874.845455, length: 349, total steps: 57561
# Track generation: 1779..2220 -> 441-tiles track
# Actions so far :